# %%
import os
import sys
TOP_DIR = os.path.dirname(os.path.dirname(os.path.realpath('__file__')))
sys.path.insert(0, os.path.join(TOP_DIR))
from config import CORE_DATA_DIR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_data = CORE_DATA_DIR + '/input_data/google_trace/1_job/5_mins.csv'
df = pd.read_csv(file_data, header=None)

# %%
df.head(10)
# Out:
#      0     1     2         3         4         5         6         7   \
# 0   600  3089  3089  0.668381  0.158746  0.351781  0.018816  0.030655
# 1   900  3089  3089  0.739129  0.164337  0.360930  0.019065  0.032660
# 2  1200  3089  3089  0.558318  0.164920  0.362985  0.019132  0.033352
# 3  1500  3090  3090  0.539101  0.156563  0.338544  0.017856  0.031283
# 4  1800  3089  3089  0.959187  0.187371  0.415752  0.020973  0.037244
# 5  2100  3090  3090  1.210667  0.206957  0.467051  0.023006  0.041250
# 6  2400  3089  3089  0.418271  0.170290  0.375985  0.021388  0.038557
# 7  2700  3089  3089  0.636748  0.173151  0.382268  0.019825  0.034842
# 8  3000  3089  3089  0.603122  0.161668  0.360351  0.018604  0.031803
# 9  3300  3089  3089  0.806979  0.168496  0.377811  0.018721  0.031406
#
#          8         9         10        11        12          13        14  15  \
# 0  0.189231  0.006224  0.004191  5.339330  0.761954  182.528000  0.388110   0
# ...

# %%
df.boxplot(column=[4])

# %%
meanCPUUsage, canonical_memory_usage = 3, 4

# %%
def plot_data(df, column_index, figsize=(25, 20), title=None):
    df1 = df.iloc[:, column_index]
    df1.plot(linewidth=0.5, figsize=figsize, title=title)
    plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
plt.plot(df[3])

# %%
plot_data(df, 3, (50, 10))

# %%
plot_data(df[400:500], meanCPUUsage, (50, 10))

# %%
plt.figure(figsize=(5, 15))
df.boxplot(column=3)

# %%
plot_data(df, canonical_memory_usage, (50, 10))

# %%
plot_data(df[400:500], canonical_memory_usage, (50, 10))

# %%
df2 = df.iloc[:, [3, 4]]
df2
# Out:
#              3         4
# 0     0.668381  0.158746
# 1     0.558318  0.164920
# 2     0.959187  0.187371
# 3     0.418271  0.170290
# 4     0.603122  0.161668
# ...        ...       ...
# 4171  1.331234  0.368009
# 4172  1.583542  0.368380
# 4173  2.185654  0.450628
# 4174  0.757450  0.385995
# 4175  1.527952  0.379241
#
# [4176 rows x 2 columns]

# %%
df3 = (df2 - df2.min()) / (df2.max() - df2.min())

# %%
df3[:200].plot(linewidth=0.5, figsize=(25, 10))
