# %%
import os
import sys
TOP_DIR = os.path.dirname(os.path.dirname(os.path.realpath('__file__')))
sys.path.insert(0, os.path.join(TOP_DIR))
from config import CORE_DATA_DIR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_data = CORE_DATA_DIR + '/input_data/google_trace/all_jobs/10_mins.csv'
df = pd.read_csv(file_data, header=None)

# %%
df.tail(10)
# Out:
#                 0            1            2   3          4             5
# 4166  2142.370961  2570.456202  3187.797403 NaN  11.583059  2.500200e+12
# 4167  2215.761468  2582.590140  3205.957306 NaN  11.686481  2.500800e+12
# 4168  2007.802423  2550.488691  3173.877864 NaN  11.711265  2.501400e+12
# 4169  2204.470537  2541.654075  3171.804328 NaN  11.773603  2.502000e+12
# 4170  2164.983654  2545.667817  3173.104984 NaN  11.796462  2.502600e+12
# 4171  2165.157878  2586.021283  3218.405884 NaN  11.873598  2.503200e+12
# 4172  2240.851202  2557.472906  3182.289948 NaN  11.852536  2.503800e+12
# 4173  2251.404098  2579.619145  3205.859309 NaN  11.847714  2.504400e+12
# 4174  2126.824759  2566.671656  3194.628510 NaN  11.889292  2.505000e+12
# 4175  2112.884150  2573.267071  3206.481273 NaN  11.896574  2.505600e+12

# %%
df.boxplot(column=[0])

# %%
meanCPUUsage, canonical_memory_usage = 3, 4

# %%
def plot_data(df, column_index, figsize=(25, 20), title=None):
    df1 = df.iloc[:, column_index]
    df1.plot(linewidth=0.5, figsize=figsize, title=title)
    plt.show()

# %%
plot_data(df, 0, (50, 10))

# %%
plot_data(df[400:500], meanCPUUsage, (50, 10))

# %%
plt.figure(figsize=(5, 15))
df.boxplot(column=3)

# %%
plot_data(df, canonical_memory_usage, (50, 10))

# %%
plot_data(df[400:500], canonical_memory_usage, (50, 10))

# %%
df2 = df.iloc[:, [3, 4]]
df2
# Out:
#              3         4
# 0     0.668381  0.158746
# 1     0.558318  0.164920
# 2     0.959187  0.187371
# 3     0.418271  0.170290
# 4     0.603122  0.161668
# ...        ...       ...
# 4171  1.331234  0.368009
# 4172  1.583542  0.368380
# 4173  2.185654  0.450628
# 4174  0.757450  0.385995
# 4175  1.527952  0.379241
#
# [4176 rows x 2 columns]

# %%
df3 = (df2 - df2.min()) / (df2.max() - df2.min())

# %%
df3[:200].plot(linewidth=0.5, figsize=(25, 10))
